# %% [markdown]
# # Projecto Final

# %%
import pandas as pd
import numpy as np

# %%
def read_data(filename):
    return pd.read_csv(filename, on_bad_lines='skip')

# %%
data_2 = read_data("../Dataset/C - Body posture features 2.csv")
data_4 = read_data("../Dataset/C - Body posture features 4.csv")

data_2 = data_2.drop_duplicates()
data_4 = data_4.drop_duplicates()

del data_4['Unnamed: 2'] 
del data_2['Added'] 
del data_2['Blok']

cols_2, cols_4 = list(data_2), list(data_4)

# %%
len(cols_2), len(cols_4)
# Out:
# (97, 97)

# %%
data_2 = data_2.sort_values('timestamp')
data_4 = data_4.sort_values('timestamp')

# %%
#data_1.to_csv('../Dataset/generated/C_1.csv', index=False) 
#data_4.to_csv('../Dataset/generated/C_4.csv', index=False)

# %%
data_2.shape, data_4.shape
# Out:
# ((3139, 97), (3235, 97))

# %%
import matplotlib.pyplot as plt

N = 3000

for feature in list(data_2)[3:30]:
    x = data_2[feature][:N].values.tolist()
    y = data_4[feature][:N].values.tolist()
    x = [float(i) for i in x]

    fig = plt.figure()

    plt.xlim(min(x), max(x))
    plt.ylim(min(y), max(y))
    plt.scatter(x, y, s=25, alpha=0.5)
    fig.text(.5, .0001, feature, ha='center')
    plt.show()
