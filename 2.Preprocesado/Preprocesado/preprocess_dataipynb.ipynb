# %%
from utils import *

# %% [markdown]
# # Preprocesado

# %% [markdown]
# El preprocesado de datos se hace con una función diseña por el equipo de desarrollo para que pueda imputar los valores nulos o nan de manera automática con la media, mediana o moda.
# Al igual se incluye una pipeline donde se llama a una función auto_dsata transorm la cual transforma los datos según su distribución.

# %%
df = cargar_datos_csv("full_dataset.csv")
categorical_features = ['Blok', 'Condition','momento_dia']
numeric_features = df.select_dtypes(include=['float64']).columns.tolist()
# Out:
# Datos cargados correctamente: full_dataset.csv

# %%
preprocesed = apply_preprocessing(df,numeric_features,categorical_features)
# Out:
# /content/utils.py:582: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mean(), inplace=True)
# Shape de P_preprocessed: (3139, 158)
# Cantidad de nombres en columns_names: 158

# %%
pd.set_option('display.max_rows', None)
preprocesed.describe().T
# Out:
#                                                      count          mean  \
# SnMouseAct                                          3139.0 -2.625771e-16
# SnLeftClicked                                       3139.0 -1.041254e-16
# SnRightClicked                                      3139.0  8.375305e-17
# SnDoubleClicked                                     3139.0 -9.054383e-17
# SnWheel                                             3139.0  0.000000e+00
# SnDragged                                           3139.0 -9.280743e-17
# SnMouseDistance                                     3139.0  1.358158e-17
# SnKeyStrokes                                        3139.0  7.160025e+00
# SnChars                                             3139.0  1.810877e-17
# SnSpecialKeys                                       3139.0  1.810877e-17
# SnDirectionKeys                                     3139.0  3.169034e-17
# SnErrorKeys                                         3139.0  7.243507e-17
# ...

# %%
preprocesed_num_cols = columnas_numericas = preprocesed.select_dtypes(include=['number']).columns.tolist()
correlacion(preprocesed,preprocesed_num_cols)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# No capta el momento día mañana que serí mucho más interesante que momento día noche, que tal un label_ecoder?
