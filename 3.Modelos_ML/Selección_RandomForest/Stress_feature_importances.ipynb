# %%
from utils import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import xgboost as xgb
import optuna

from utils import *
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# ! pip install openpyxl

# %% [markdown]
# En este notebook voy a aplicar random forest con optimización de parámetros a :
#
#  * Behavioral-features-per mimnute
#  * concatenación de ambos

# %% [markdown]
# # 1. Estudio Behavioral-features-per minute

# %% [markdown]
# ## Carga dataset

# %%
df_Stress = pd.read_excel("Copia de Behavioral-features - per minute.xlsx")

# %% [markdown]
# ## 1.1 primera prueba
# * Regresor
# * Stratify = codition
# * Imputer = mediana
# * Escalado StandardScaler
# * Eliminadas columnas correlacionadas > 0.8

# %%
# Hago una copia del dataframe para no modificar el original
df_stress = df_Stress.copy()
#Eliminamos columnas que no son compatibles con nuestro problema ya que no tendremos esas features en nuestro datos de entrada de nuestra APP
columnas_a_eliminar = ['PP','timestamp','HR','RMSSD', 'RMSSD','SCL','Valence_rc','Arousal_rc',
                       'Dominance','MentalEffort','MentalDemand','PhysicalDemand','TemporalDemand',
                       'Effort','Performance_rc','Frustration','NasaTLX','Squality','Sneutral','Shappy',
                       'Ssad','Sangry','Ssurprised','Sscared','Sdisgusted','Svalence']
df_stress = df_stress.drop(columnas_a_eliminar, axis=1)
#Filtramos filas que tengan condición diferente a 'R'
df_stress = df_stress[df_stress['Condition'] != 'R']
#Dividimos los datos : voy a estrtificar por condition
X = df_stress.drop('Stress', axis=1)
y = df_stress['Stress']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42, stratify=df_stress['Condition']) # probar con stratify = 'Blok'
# Variables categóricas
categorical_features = ['Condition','Blok']
#convertir en categoricas
X_train[categorical_features] = X_train[categorical_features].astype('category')
#Aplicamos one hot encoding
X_train = pd.get_dummies(X_train, columns=categorical_features)
# Variables numéricas
numeric_features = X_train.select_dtypes(include=[np.number]).columns.tolist()
# Imputación de valores nulos
imputer = SimpleImputer(strategy='most_frequent') # probar con media
#Entrenamos el imputer
imputer.fit(X_train[numeric_features])
#Aplicamos la transformación
X_train[numeric_features] = imputer.transform(X_train[numeric_features])
# Normalización
scaler = StandardScaler()
scaler.fit(X_train[numeric_features])
X_train[numeric_features] = scaler.transform(X_train[numeric_features])
# matriz de correlación
corr = X_train.corr().abs()
# Seleccionar las columnas con correlación > 0.8 (excepto la diagonal)
high_corr_cols = set()
for i in range(len(corr.columns)):
    for j in range(i):
        if corr.iloc[i, j] > 0.8:
            colname = corr.columns[i]
            high_corr_cols.add(colname)
# Eliminar las columnas redundantes en X_train
X_train.drop(columns=high_corr_cols, inplace=True)
print(f"Eliminadas {len(high_corr_cols)} columnas altamente correlacionadas entre sí (sin considerar 'Stress').")
print(f"Columnas eliminadas: {list(high_corr_cols)}")

# Aplicamos las mismas transformaciones a X_test
X_test[categorical_features] = X_test[categorical_features].astype('category')
X_test = pd.get_dummies(X_test, columns=categorical_features)
X_test[numeric_features] = imputer.transform(X_test[numeric_features])
X_test[numeric_features] = scaler.transform(X_test[numeric_features])
X_test.drop(columns=high_corr_cols, inplace=True)

# OPTIMIZACIÓN DE HIPERPARÁMETROS CON OPTUNA
def objective(trial):
    # Parámetros a optimizar
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 250, 300, step=50), # probado con 100, 200, 300
        #'max_depth': trial.suggest_int('max_depth', 5, 50),
        #'min_samples_split': trial.suggest_int('min_samples_split', 2, 20), # min_samples_split=2 es el default, no tiene sentido optimizarlo
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 2), 
        #'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2']), # esto no optimiza nada
        #'criterion': trial.suggest_categorical('criterion', ['squared_error', 'absolute_error', 'poisson']),
        #'max_samples': trial.suggest_float('max_samples', 0.5, 1.0, step=0.1),
    }
    
    # Modelo
    model = RandomForestRegressor(**params, random_state=42)
    
    # Validación cruzada
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
    
    return -score.mean()

# Crear estudio
study = optuna.create_study(direction='minimize')

# Optimización
study.optimize(objective, n_trials=10)

# Mejor resultado encontrado
print("Mejores parámetros:", study.best_params)
 
# mejor metrica
best_value = study.best_value
print(f"Mejor valor: {best_value}")
#Raiz cuadrada del mejor valor
best_value = np.sqrt(best_value)
print(f"Raíz cuadrada del mejor valor: {best_value}")
# Out:
# [I 2025-03-20 07:51:55,383] A new study created in memory with name: no-name-97357304-f592-466f-88a6-f4f9e1fe28ea
# Eliminadas 43 columnas altamente correlacionadas entre sí (sin considerar 'Stress').
# Columnas eliminadas: ['HipCenter_SpinePlaneYZAxisZavg', 'ShoulderCenter_ShoulderRightPlaneYZAxisZstdv', 'SnChars', 'ShoulderCenter_ShoulderRightPlaneYZAxisZavg', 'Spine_ShoulderCenterShoulderCenter_ShoulderRightavg', 'Spine_ShoulderCenterPlaneYZAxisZstdv', 'WristLeft_HandLeftPlaneXYAxisYavg', 'Spine_ShoulderCenterShoulderCenter_ShoulderLeftavg', 'Blok_1', 'Spine_ShoulderCenterShoulderCenter_Headavg', 'ShoulderCenter_ShoulderLeftPlaneXYAxisYstdv', 'Spine_ShoulderCenterPlaneXYAxisYstdv', 'ShoulderCenter_ShoulderLeftShoulderLeft_ElbowLeftavg', 'leanAngleavg', 'SnDragged', 'SnSpecialKeys', 'ShoulderCenter_HeadPlaneXYAxisYavg', 'SrightEyeClosed', 'Spine_ShoulderCenterPlaneXYAxisYavg', 'ShoulderCenter_ShoulderRightPlaneZXAxisXavg', 'SAu43_EyesClosed', 'ElbowLeft_WristLeftWristLeft_HandLeftavg', 'HipCenter_SpinePlaneYZAxisZstdv', 'ShoulderCenter_ShoulderRightPlaneXYAxisYstdv', 'SnSpaces', 'ShoulderRight_ElbowRightPlaneZXAxisXavg', 'HipCenter_SpinePlaneXYAxisYavg', 'WristRight_HandRightPlaneXYAxisYavg', 'SAu25_LipsPart', 'ShoulderLeft_ElbowLeftElbowLeft_WristLeftavg', 'ShoulderCenter_ShoulderLeftPlaneYZAxisZstdv', 'ShoulderCenter_ShoulderRightPlaneXYAxisYavg', 'HipCenter_SpinePlaneZXAxisXavg', 'ElbowRight_WristRightWristRight_HandRightavg', 'WristLeft_HandLeftPlaneZXAxisXavg', 'ShoulderCenter_HeadPlaneYZAxisZavg', 'SnLeftClicked', 'WristRight_HandRightPlaneZXAxisXavg', 'Spine_ShoulderCenterShoulderCenter_Headstdv', 'SAu10_UpperLipRaiser', 'Spine_ShoulderCenterPlaneYZAxisZavg', 'Spine_ShoulderCenterShoulderCenter_ShoulderLeftstdv', 'ShoulderCenter_ShoulderLeftPlaneXYAxisYavg']
# [I 2025-03-20 07:53:35,397] Trial 0 finished with value: 0.9690722359186893 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.9690722359186893.
# [I 2025-03-20 07:55:21,737] Trial 1 finished with value: 0.9594231337674411 and parameters: {'n_estimators': 250, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.9594231337674411.
# [I 2025-03-20 07:57:02,054] Trial 2 finished with value: 0.9690722359186893 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9594231337674411.
# [I 2025-03-20 07:59:09,577] Trial 3 finished with value: 0.9594423890956054 and parameters: {'n_estimators': 300, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.9594231337674411.
# [I 2025-03-20 08:00:49,571] Trial 4 finished with value: 0.9690722359186893 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9594231337674411.
# [I 2025-03-20 08:02:35,571] Trial 5 finished with value: 0.9594231337674411 and parameters: {'n_estimators': 250, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.9594231337674411.
# [I 2025-03-20 08:04:16,083] Trial 6 finished with value: 0.9690722359186893 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9594231337674411.
# [I 2025-03-20 08:06:01,950] Trial 7 finished with value: 0.9594231337674411 and parameters: {'n_estimators': 250, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.9594231337674411.
# [I 2025-03-20 08:07:42,174] Trial 8 finished with value: 0.9690722359186893 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9594231337674411.
# [I 2025-03-20 08:09:22,335] Trial 9 finished with value: 0.9690722359186893 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9594231337674411.
# Mejores parámetros: {'n_estimators': 250, 'min_samples_leaf': 1}
# Mejor valor: 0.9594231337674411
# Raíz cuadrada del mejor valor: 0.9795014720598643

# %% [markdown]
# ## 1.2 Segunda prueba
# * Clasificador
# * Stratify = codition
# * Imputer = mediana
# * Sin escalar
# * Eliminadas columnas correlacionadas > 0.8

# %%
# Hago una copia del dataframe para no modificar el original
df_stress = df_Stress.copy()
#Eliminamos columnas que no son compatibles con nuestro problema ya que no tendremos esas features en nuestro datos de entrada de nuestra APP
columnas_a_eliminar = ['PP','timestamp','HR','RMSSD', 'RMSSD','SCL','Valence_rc','Arousal_rc',
                       'Dominance','MentalEffort','MentalDemand','PhysicalDemand','TemporalDemand',
                       'Effort','Performance_rc','Frustration','NasaTLX','Squality','Sneutral','Shappy',
                       'Ssad','Sangry','Ssurprised','Sscared','Sdisgusted','Svalence']
df_stress = df_stress.drop(columnas_a_eliminar, axis=1)
#Filtramos filas que tengan condición diferente a 'R'
df_stress = df_stress[df_stress['Condition'] != 'R']
#Convierto variable Stress a int
df_stress['Stress'] = df_stress['Stress'].astype(int)
#Dividimos los datos : voy a estrtificar por condition
X = df_stress.drop('Stress', axis=1)
y = df_stress['Stress']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42, stratify=df_stress['Condition']) # probar con stratify = 'Blok'
# Variables categóricas
categorical_features = ['Condition','Blok']
#convertir en categoricas
X_train[categorical_features] = X_train[categorical_features].astype('category')
#Aplicamos one hot encoding
X_train = pd.get_dummies(X_train, columns=categorical_features)
# Variables numéricas
numeric_features = X_train.select_dtypes(include=[np.number]).columns.tolist()
# Imputación de valores nulos
imputer = SimpleImputer(strategy='most_frequent') # probar con media
#Entrenamos el imputer
imputer.fit(X_train[numeric_features])
#Aplicamos la transformación
X_train[numeric_features] = imputer.transform(X_train[numeric_features])
# Normalización
#scaler = StandardScaler()
#scaler.fit(X_train[numeric_features])
#X_train[numeric_features] = scaler.transform(X_train[numeric_features])
# matriz de correlación
corr = X_train.corr().abs()
# Seleccionar las columnas con correlación > 0.8 (excepto la diagonal)
high_corr_cols = set()
for i in range(len(corr.columns)):
    for j in range(i):
        if corr.iloc[i, j] > 0.8:
            colname = corr.columns[i]
            high_corr_cols.add(colname)
# Eliminar las columnas redundantes en X_train
X_train.drop(columns=high_corr_cols, inplace=True)
print(f"Eliminadas {len(high_corr_cols)} columnas altamente correlacionadas entre sí (sin considerar 'Stress').")
print(f"Columnas eliminadas: {list(high_corr_cols)}")

# Aplicamos las mismas transformaciones a X_test
X_test[categorical_features] = X_test[categorical_features].astype('category')
X_test = pd.get_dummies(X_test, columns=categorical_features)
#X_test[numeric_features] = imputer.transform(X_test[numeric_features])
#X_test[numeric_features] = scaler.transform(X_test[numeric_features])
X_test.drop(columns=high_corr_cols, inplace=True)

# OPTIMIZACIÓN DE HIPERPARÁMETROS CON OPTUNA
def objective(trial):
    # Parámetros a optimizar
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 250, 300, step=50), # probado con 100, 200, 300
        #'max_depth': trial.suggest_int('max_depth', 5, 50),
        #'min_samples_split': trial.suggest_int('min_samples_split', 2, 20), # min_samples_split=2 es el default, no tiene sentido optimizarlo
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 2), 
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample', None]),
        #'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2']), # esto no optimiza nada
        #'criterion': trial.suggest_categorical('criterion', ['squared_error', 'absolute_error', 'poisson']),
        #'max_samples': trial.suggest_float('max_samples', 0.5, 1.0, step=0.1),
    }
    
    # Modelo
    model = RandomForestClassifier(**params, random_state=42)
    
    # Validación cruzada
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
    
    return -score.mean()

# Crear estudio
study = optuna.create_study(direction='minimize')

# Optimización
study.optimize(objective, n_trials=10)

# Mejor resultado encontrado
print("Mejores parámetros:", study.best_params)
 
# mejor metrica
best_value = study.best_value
print(f"Mejor valor: {best_value}")
#Raiz cuadrada del mejor valor
best_value = np.sqrt(best_value)
print(f"Raíz cuadrada del mejor valor: {best_value}")
# Out:
# [I 2025-03-20 08:11:44,677] A new study created in memory with name: no-name-2f6be917-111a-4790-a497-eaf08a1bd1b1
# Eliminadas 43 columnas altamente correlacionadas entre sí (sin considerar 'Stress').
# Columnas eliminadas: ['HipCenter_SpinePlaneYZAxisZavg', 'ShoulderCenter_ShoulderRightPlaneYZAxisZstdv', 'SnChars', 'ShoulderCenter_ShoulderRightPlaneYZAxisZavg', 'Spine_ShoulderCenterShoulderCenter_ShoulderRightavg', 'Spine_ShoulderCenterPlaneYZAxisZstdv', 'WristLeft_HandLeftPlaneXYAxisYavg', 'Spine_ShoulderCenterShoulderCenter_ShoulderLeftavg', 'Blok_1', 'Spine_ShoulderCenterShoulderCenter_Headavg', 'ShoulderCenter_ShoulderLeftPlaneXYAxisYstdv', 'Spine_ShoulderCenterPlaneXYAxisYstdv', 'ShoulderCenter_ShoulderLeftShoulderLeft_ElbowLeftavg', 'leanAngleavg', 'SnDragged', 'SnSpecialKeys', 'ShoulderCenter_HeadPlaneXYAxisYavg', 'SrightEyeClosed', 'Spine_ShoulderCenterPlaneXYAxisYavg', 'ShoulderCenter_ShoulderRightPlaneZXAxisXavg', 'SAu43_EyesClosed', 'ElbowLeft_WristLeftWristLeft_HandLeftavg', 'HipCenter_SpinePlaneYZAxisZstdv', 'ShoulderCenter_ShoulderRightPlaneXYAxisYstdv', 'SnSpaces', 'ShoulderRight_ElbowRightPlaneZXAxisXavg', 'HipCenter_SpinePlaneXYAxisYavg', 'WristRight_HandRightPlaneXYAxisYavg', 'SAu25_LipsPart', 'ShoulderLeft_ElbowLeftElbowLeft_WristLeftavg', 'ShoulderCenter_ShoulderLeftPlaneYZAxisZstdv', 'ShoulderCenter_ShoulderRightPlaneXYAxisYavg', 'HipCenter_SpinePlaneZXAxisXavg', 'ElbowRight_WristRightWristRight_HandRightavg', 'WristLeft_HandLeftPlaneZXAxisXavg', 'ShoulderCenter_HeadPlaneYZAxisZavg', 'SnLeftClicked', 'WristRight_HandRightPlaneZXAxisXavg', 'Spine_ShoulderCenterShoulderCenter_Headstdv', 'SAu10_UpperLipRaiser', 'Spine_ShoulderCenterPlaneYZAxisZavg', 'Spine_ShoulderCenterShoulderCenter_ShoulderLeftstdv', 'ShoulderCenter_ShoulderLeftPlaneXYAxisYavg']
# [I 2025-03-20 08:12:02,895] Trial 0 finished with value: 0.4586046511627907 and parameters: {'n_estimators': 300, 'min_samples_leaf': 1, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.4586046511627907.
# [I 2025-03-20 08:12:16,628] Trial 1 finished with value: 0.3483720930232558 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.3483720930232558.
# [I 2025-03-20 08:12:34,048] Trial 2 finished with value: 0.3511627906976744 and parameters: {'n_estimators': 300, 'min_samples_leaf': 2, 'class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.3483720930232558.
# [I 2025-03-20 08:12:47,746] Trial 3 finished with value: 0.3483720930232558 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.3483720930232558.
# [I 2025-03-20 08:13:05,013] Trial 4 finished with value: 0.43162790697674425 and parameters: {'n_estimators': 300, 'min_samples_leaf': 1, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.3483720930232558.
# [I 2025-03-20 08:13:19,364] Trial 5 finished with value: 0.40930232558139534 and parameters: {'n_estimators': 250, 'min_samples_leaf': 1, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.3483720930232558.
# [I 2025-03-20 08:13:34,596] Trial 6 finished with value: 0.4213953488372093 and parameters: {'n_estimators': 250, 'min_samples_leaf': 1, 'class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.3483720930232558.
# [I 2025-03-20 08:13:49,850] Trial 7 finished with value: 0.6590697674418605 and parameters: {'n_estimators': 300, 'min_samples_leaf': 2, 'class_weight': None}. Best is trial 1 with value: 0.3483720930232558.
# [I 2025-03-20 08:14:04,513] Trial 8 finished with value: 0.3781395348837209 and parameters: {'n_estimators': 250, 'min_samples_leaf': 2, 'class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.3483720930232558.
# [I 2025-03-20 08:14:23,201] Trial 9 finished with value: 0.4586046511627907 and parameters: {'n_estimators': 300, 'min_samples_leaf': 1, 'class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.3483720930232558.
# Mejores parámetros: {'n_estimators': 250, 'min_samples_leaf': 2, 'class_weight': 'balanced'}
# Mejor valor: 0.3483720930232558
# Raíz cuadrada del mejor valor: 0.5902305422656945

# %%
#Entrenar Modelo con los Mejores Parámetros
# Modelo
model = RandomForestClassifier(**study.best_params, random_state=42)
# Entrenamiento
model.fit(X_train, y_train)
# Predicción
y_pred_train = model.predict(X_train)
# Métricas
mse = mean_squared_error(y_train, y_pred_train)
r2 = r2_score(y_train, y_pred_train)
mae = mean_absolute_error(y_train, y_pred_train)
print(f"Mean Squared Error: {mse}")
print(f"R^2: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 0.0
# R^2: 1.0
# Mean Absolute Error: 0.0

# %%
#Entrenar Modelo con los Mejores Parámetros
# Modelo
model = RandomForestClassifier(**study.best_params, random_state=42)
# Entrenamiento
model.fit(X_test, y_test)
# Predicción
y_pred_test = model.predict(X_test)
# Métricas
mse = mean_squared_error(y_test, y_pred_test)
r2 = r2_score(y_test, y_pred_test)
mae = mean_absolute_error(y_test, y_pred_test)
print(f"Mean Squared Error: {mse}")
print(f"R^2: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 0.016728624535315983
# R^2: 0.9964214156323976
# Mean Absolute Error: 0.0055762081784386614

# %% [markdown]
# # Notebook sin tocar

# %%
df_full_dataset = cargar_datos_csv("full_dataset.csv")

# Elimino las filas donde Condition = 'R'
df_full_dataset = df_full_dataset.loc[df_full_dataset['Condition'] != 'R']
# Out:
# Datos cargados correctamente: full_dataset.csv

# %%
# Lectura archivo excel para extraer característica estrés
df_Stress = pd.read_excel("Copia de Behavioral-features - per minute.xlsx", usecols=["PP", "Blok", "Condition", "Stress"])  # Carga solo columnas indicadas
# Elimino las filas donde Condition = 'R'
df_Stress = df_Stress.loc[df_Stress['Condition'] != 'R']

# %%
# Verificar si las columnas son iguales
iguales = df_full_dataset['PP'].equals(df_Stress['PP']) and df_full_dataset['Condition'].equals(df_Stress['Condition']) and df_full_dataset['Blok'].equals(df_Stress['Blok'])

if iguales:
    print("Las colunas son idénticos")
else:
    print("Las columnas tienen diferencias entre los datasets.")
# Out:
# Las colunas son idénticos

# %% [markdown]
# # Importancia de las caracteríticas sin escalado

# %%
pd.set_option('display.max_rows', None)  # Todas las filas

# %%
# Definimos la variable objetivo (target)
target = df_Stress['Stress'].astype(int)  # Convertimos a entero para asegurar que sea categórica

# Seleccionamos solo las columnas numéricas y eliminamos la variable objetivo
df_full_dataset_num = df_full_dataset.select_dtypes(include=[np.number])

# Manejo de valores NaN (rellenamos con la mediana de cada columna)
X = df_full_dataset_num.fillna(df_full_dataset_num.median())
y = target

# Creación del modelo Random Forest con balanceo de clases
rnd_clf = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
rnd_clf.fit(X, y)

# Obtener la importancia de las características
feature_importances = rnd_clf.feature_importances_

# Mostrar resultados ordenados
feature_importance_df_full = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
feature_importance_df_full = feature_importance_df_full.sort_values(by='Importance', ascending=False)

# Imprimir la importancia de las características

for i, (feature, importance) in enumerate(zip(feature_importance_df_full['Feature'], feature_importance_df_full['Importance']), 1):
    print(f"{i}. {feature}: {round(importance, 4)}")
# Out:
# 1. SzHeadOrientation: 0.0281
# 2. avgDepth(avg): 0.0281
# 3. Blok: 0.0215
# 4. Squality: 0.0206
# 5. WristLeft_HandLeft-PlaneZXAxisX(avg): 0.019
# 6. ShoulderCenter_Head-PlaneYZAxisZ(avg): 0.0174
# 7. SAu01_InnerBrowRaiser: 0.0159
# 8. avgDepth(stdv): 0.0157
# 9. SyHeadOrientation: 0.0157
# 10. Ssurprised: 0.015
# 11. WristLeft_HandLeft-PlaneXYAxisY(avg): 0.015
# 12. WristLeft_HandLeft-PlaneZXAxisX(stdv): 0.0149
# 13. ShoulderLeft_ElbowLeft-ElbowLeft_WristLeft(avg): 0.0146
# 14. HipCenter_Spine-Spine_ShoulderCenter(avg): 0.0142
# 15. ShoulderCenter_ShoulderLeft-PlaneXYAxisY(avg): 0.014
# 16. WristLeft_HandLeft-PlaneYZAxisZ(avg): 0.0138
# 17. ShoulderCenter_Head-PlaneZXAxisX(avg): 0.0137
# 18. leftShoulderAngle(avg): 0.0133
# 19. Spine_ShoulderCenter-ShoulderCenter_ShoulderLeft(avg): 0.0127
# 20. ElbowLeft_WristLeft-PlaneYZAxisZ(avg): 0.0127
# 21. SAu10_UpperLipRaiser: 0.0124
# 22. SAu06_CheekRaiser: 0.0123
# 23. SrightEyebrowLowered: 0.0119
# 24. ShoulderLeft_ElbowLeft-PlaneYZAxisZ(avg): 0.0116
# 25. Sscared: 0.0113
# 26. Sangry: 0.011
# 27. ShoulderCenter_Head-PlaneXYAxisY(avg): 0.0109
# 28. SxHeadOrientation: 0.0108
# 29. ShoulderCenter_ShoulderRight-PlaneZXAxisX(avg): 0.0106
# 30. SrightEyebrowRaised: 0.0101
# 31. ElbowLeft_WristLeft-PlaneXYAxisY(avg): 0.0101
# 32. Sneutral: 0.01
# 33. Sdisgusted: 0.01
# 34. rightShoulderAngle(avg): 0.01
# 35. Ssad: 0.0093
# 36. SAu02_OuterBrowRaiser: 0.0089
# 37. ShoulderCenter_ShoulderRight-PlaneYZAxisZ(avg): 0.0088
# 38. ElbowLeft_WristLeft-PlaneZXAxisX(avg): 0.0088
# 39. SAu04_BrowLowerer: 0.0086
# 40. ShoulderCenter_ShoulderLeft-PlaneYZAxisZ(avg): 0.0085
# 41. SAu23_LipTightener: 0.0083
# 42. ShoulderCenter_ShoulderLeft-ShoulderLeft_ElbowLeft(avg): 0.0083
# 43. ShoulderCenter_ShoulderRight-PlaneXYAxisY(avg): 0.0082
# 44. SleftEyebrowRaised: 0.0079
# 45. SAu05_UpperLidRaiser: 0.0078
# 46. Spine_ShoulderCenter-ShoulderCenter_Head(avg): 0.0077
# 47. SAu14_Dimpler: 0.0077
# 48. ElbowLeft_WristLeft-PlaneZXAxisX(stdv): 0.0076
# 49. Svalence: 0.0075
# 50. SAu17_ChinRaiser: 0.0075
# 51. Spine_ShoulderCenter-ShoulderCenter_ShoulderRight(avg): 0.0074
# 52. SAu43_EyesClosed: 0.0074
# 53. HipCenter_Spine-PlaneYZAxisZ(avg): 0.0073
# 54. SAu07_LidTightener: 0.007
# 55. Spine_ShoulderCenter-PlaneYZAxisZ(avg): 0.007
# 56. ShoulderCenter_ShoulderLeft-PlaneZXAxisX(avg): 0.007
# 57. leanAngle(avg): 0.0069
# 58. ElbowLeft_WristLeft-WristLeft_HandLeft(avg): 0.0069
# 59. HipCenter_Spine-PlaneXYAxisY(avg): 0.0068
# 60. Shappy: 0.0066
# 61. SleftEyebrowLowered: 0.0066
# 62. SleftEyeClosed: 0.0065
# 63. ShoulderCenter_ShoulderRight-ShoulderRight_ElbowRight(avg): 0.0063
# 64. ShoulderRight_ElbowRight-ElbowRight_WristRight(avg): 0.0063
# 65. ShoulderLeft_ElbowLeft-PlaneZXAxisX(avg): 0.0062
# 66. SgazeDirectionLeft: 0.0061
# 67. SgazeDirectionForward: 0.0058
# 68. ShoulderRight_ElbowRight-PlaneXYAxisY(avg): 0.0058
# 69. ShoulderRight_ElbowRight-PlaneZXAxisX(avg): 0.0057
# 70. HipCenter_Spine-PlaneZXAxisX(avg): 0.0056
# 71. WristLeft_HandLeft-PlaneYZAxisZ(stdv): 0.0055
# 72. Spine_ShoulderCenter-PlaneXYAxisY(avg): 0.0055
# 73. SmouthOpen: 0.0054
# 74. Spine_ShoulderCenter-PlaneZXAxisX(avg): 0.0052
# 75. SrightEyeClosed: 0.0051
# 76. HipCenter_Spine-Spine_ShoulderCenter(stdv): 0.0049
# 77. SAu15_LipCornerDepressor: 0.0049
# 78. SAu24_LipPressor: 0.0049
# 79. SAu25_LipsPart: 0.0048
# 80. ShoulderLeft_ElbowLeft-PlaneXYAxisY(avg): 0.0048
# 81. ElbowRight_WristRight-PlaneZXAxisX(avg): 0.0045
# 82. ElbowRight_WristRight-PlaneYZAxisZ(avg): 0.0045
# 83. ElbowLeft_WristLeft-PlaneXYAxisY(stdv): 0.0041
# 84. ShoulderLeft_ElbowLeft-PlaneZXAxisX(stdv): 0.0041
# 85. ShoulderCenter_ShoulderRight-PlaneYZAxisZ(stdv): 0.004
# 86. Spine_ShoulderCenter-PlaneZXAxisX(stdv): 0.0039
# 87. SnKeyStrokes: 0.0039
# 88. ShoulderRight_ElbowRight-PlaneYZAxisZ(avg): 0.0038
# 89. SnSpecialKeys: 0.0038
# 90. ElbowLeft_WristLeft-PlaneYZAxisZ(stdv): 0.0038
# 91. WristRight_HandRight-PlaneXYAxisY(avg): 0.0036
# 92. ShoulderCenter_Head-PlaneZXAxisX(stdv): 0.0036
# 93. SnMouseAct: 0.0036
# 94. ShoulderCenter_ShoulderRight-PlaneXYAxisY(stdv): 0.0036
# 95. WristRight_HandRight-PlaneZXAxisX(avg): 0.0035
# 96. WristLeft_HandLeft-PlaneXYAxisY(stdv): 0.0035
# 97. HipCenter_Spine-PlaneYZAxisZ(stdv): 0.0035
# 98. WristRight_HandRight-KinectZAxis(stdv): 0.0035
# 99. SnChars: 0.0034
# 100. ElbowRight_WristRight-PlaneXYAxisY(avg): 0.0033
# 101. ShoulderRight_ElbowRight-PlaneXYAxisY(stdv): 0.0033
# 102. HipCenter_Spine-PlaneZXAxisX(stdv): 0.0033
# 103. Spine_ShoulderCenter-ShoulderCenter_ShoulderRight(stdv): 0.0033
# 104. ShoulderCenter_ShoulderLeft-PlaneYZAxisZ(stdv): 0.0032
# 105. ShoulderRight_ElbowRight-PlaneZXAxisX(stdv): 0.0032
# 106. ElbowLeft_WristLeft-WristLeft_HandLeft(stdv): 0.0031
# 107. SnSpaces: 0.0031
# 108. SAu09_NoseWrinkler: 0.0031
# 109. ElbowRight_WristRight-WristRight_HandRight(stdv): 0.003
# 110. ShoulderLeft_ElbowLeft-PlaneXYAxisY(stdv): 0.003
# 111. rightShoulderAngle(stdv): 0.003
# 112. Spine_ShoulderCenter-ShoulderCenter_ShoulderLeft(stdv): 0.003
# 113. SnLeftClicked: 0.0029
# 114. SgazeDirectionRight: 0.0029
# 115. ShoulderCenter_ShoulderLeft-ShoulderLeft_ElbowLeft(stdv): 0.0029
# 116. ShoulderCenter_ShoulderRight-PlaneZXAxisX(stdv): 0.0029
# 117. ShoulderLeft_ElbowLeft-ElbowLeft_WristLeft(stdv): 0.0027
# 118. Spine_ShoulderCenter-PlaneYZAxisZ(stdv): 0.0027
# 119. WristRight_HandRight-PlaneZXAxisX(stdv): 0.0027
# 120. HipCenter_Spine-PlaneXYAxisY(stdv): 0.0027
# 121. leftShoulderAngle(stdv): 0.0027
# 122. SAu26_JawDrop: 0.0026
# 123. leanAngle(stdv): 0.0026
# 124. ElbowRight_WristRight-PlaneYZAxisZ(stdv): 0.0025
# 125. ElbowRight_WristRight-PlaneZXAxisX(stdv): 0.0025
# 126. ElbowRight_WristRight-PlaneXYAxisY(stdv): 0.0024
# 127. ShoulderRight_ElbowRight-PlaneYZAxisZ(stdv): 0.0024
# 128. ShoulderCenter_ShoulderLeft-PlaneXYAxisY(stdv): 0.0024
# 129. WristRight_HandRight-PlaneXYAxisY(stdv): 0.0024
# 130. SnMouseDistance: 0.0024
# 131. WristRight_HandRight-KinectZAxis(avg): 0.0023
# 132. SnErrorKeys: 0.0023
# 133. ElbowRight_WristRight-WristRight_HandRight(avg): 0.0023
# 134. ShoulderCenter_ShoulderLeft-PlaneZXAxisX(stdv): 0.0023
# 135. ShoulderCenter_Head-PlaneXYAxisY(stdv): 0.0023
# 136. Spine_ShoulderCenter-PlaneXYAxisY(stdv): 0.0021
# 137. ShoulderCenter_ShoulderRight-ShoulderRight_ElbowRight(stdv): 0.002
# 138. SnAppChange: 0.002
# 139. Spine_ShoulderCenter-ShoulderCenter_Head(stdv): 0.002
# 140. ShoulderRight_ElbowRight-ElbowRight_WristRight(stdv): 0.002
# 141. SAu20_LipStretcher: 0.002
# 142. ShoulderLeft_ElbowLeft-PlaneYZAxisZ(stdv): 0.002
# 143. ShoulderCenter_Head-PlaneYZAxisZ(stdv): 0.0019
# 144. SnDragged: 0.0017
# 145. SnWheel: 0.0016
# 146. SnShortcutKeys: 0.0015
# 147. SnTabfocusChange: 0.0013
# 148. SnDirectionKeys: 0.0012
# 149. SAu27_MouthStretch: 0.0011
# 150. SAu12_LipCornerPuller: 0.0007
# 151. SnDoubleClicked: 0.0006
# 152. SnRightClicked: 0.0003

# %%
feature_importance_df_full[0:10]
# Out:
#                                    Feature  Importance
# 28                       SzHeadOrientation    0.028093
# 58                           avgDepth(avg)    0.028075
# 0                                     Blok    0.021539
# 17                                Squality    0.020639
# 93    WristLeft_HandLeft-PlaneZXAxisX(avg)    0.019006
# 80   ShoulderCenter_Head-PlaneYZAxisZ(avg)    0.017383
# 39                   SAu01_InnerBrowRaiser    0.015911
# 105                         avgDepth(stdv)    0.015728
# 26                       SyHeadOrientation    0.015722
# 22                              Ssurprised    0.015021

# %% [markdown]
# Los resultados no son satisfactoruios en nungún caso. importancia de características están entre 0% y 2%. Quizá la variable 'Stress' está definiida principalmete por el cuetionario final de cda participante.
# Vamos aprobar en el dataset Behavioral-features, donde está esta variable

# %% [markdown]
# Importancia de las características en dataset de variable Stress

# %%
# Lectura del archivo Excel
df_Stress = pd.read_excel("Copia de Behavioral-features - per minute.xlsx")

# Eliminamos las filas donde 'Condition' es 'R'
df_Stress = df_Stress.loc[df_Stress['Condition'] != 'R']
print(df_Stress['Condition'].value_counts())

# Definimos la variable objetivo (target)
target = df_Stress['Stress'].astype(int)  # Convertimos a entero para asegurar que sea categórica

# Seleccionamos solo las columnas numéricas y eliminamos la variable objetivo
df_numericas_Stress = df_Stress.select_dtypes(include=['number']).drop(columns=['Stress'], errors='ignore')

# Manejo de valores NaN (rellenamos con la mediana de cada columna)
X = df_numericas_Stress.fillna(df_numericas_Stress.median())
y = target

# Creación del modelo Random Forest con balanceo de clases
rnd_clf = RandomForestClassifier(n_estimators=500, random_state=42, class_weight='balanced')
rnd_clf.fit(X, y)

# Obtener la importancia de las características
feature_importances = rnd_clf.feature_importances_

# Mostrar resultados ordenados
feature_importance_df_Stress = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
feature_importance_df_Stress = feature_importance_df_Stress.sort_values(by='Importance', ascending=False)

# Imprimir la importancia de las características
for i, (feature, importance) in enumerate(zip(feature_importance_df_Stress['Feature'], feature_importance_df_Stress['Importance']), 1):
    print(f"{i}. {feature}: {round(importance, 4)}")
# Out:
# Condition
# N    1028
# I     996
# T     664
# Name: count, dtype: int64
# 1. NasaTLX: 0.0547
# 2. TemporalDemand: 0.0538
# 3. Frustration: 0.0533
# 4. MentalDemand: 0.049
# 5. Performance_rc: 0.0471
# 6. Effort: 0.0465
# 7. MentalEffort: 0.0451
# 8. Arousal_rc: 0.0353
# 9. PhysicalDemand: 0.034
# 10. Valence_rc: 0.032
# 11. SCL: 0.0245
# 12. Dominance: 0.0194
# 13. avgDepthavg: 0.0171
# 14. Blok: 0.0121
# 15. SzHeadOrientation: 0.0115
# 16. ShoulderCenter_HeadPlaneYZAxisZavg: 0.0109
# 17. Squality: 0.0095
# 18. Ssurprised: 0.0093
# 19. SAu01_InnerBrowRaiser: 0.009
# 20. ShoulderCenter_HeadPlaneZXAxisXavg: 0.0086
# 21. HipCenter_SpineSpine_ShoulderCenteravg: 0.0085
# 22. WristLeft_HandLeftPlaneZXAxisXavg: 0.0076
# 23. leftShoulderAngleavg: 0.0075
# 24. avgDepthstdv: 0.0075
# 25. WristLeft_HandLeftPlaneZXAxisXstdv: 0.0073
# 26. Sdisgusted: 0.0073
# 27. Spine_ShoulderCenterShoulderCenter_ShoulderLeftavg: 0.0071
# 28. ShoulderCenter_ShoulderLeftPlaneXYAxisYavg: 0.007
# 29. WristLeft_HandLeftPlaneYZAxisZavg: 0.007
# 30. ShoulderLeft_ElbowLeftElbowLeft_WristLeftavg: 0.007
# 31. WristLeft_HandLeftPlaneXYAxisYavg: 0.0067
# 32. SyHeadOrientation: 0.0065
# 33. ShoulderCenter_ShoulderRightPlaneZXAxisXavg: 0.0063
# 34. ElbowLeft_WristLeftPlaneYZAxisZavg: 0.0063
# 35. SAu06_CheekRaiser: 0.006
# 36. Sscared: 0.0059
# 37. ShoulderCenter_HeadPlaneXYAxisYavg: 0.0059
# 38. ElbowLeft_WristLeftPlaneXYAxisYavg: 0.0059
# 39. ShoulderLeft_ElbowLeftPlaneYZAxisZavg: 0.0058
# 40. Sangry: 0.0058
# 41. ElbowLeft_WristLeftPlaneZXAxisXavg: 0.0056
# 42. HipCenter_SpinePlaneYZAxisZavg: 0.0056
# 43. SrightEyebrowLowered: 0.0054
# 44. ShoulderCenter_ShoulderRightPlaneXYAxisYavg: 0.0054
# 45. ShoulderCenter_ShoulderRightPlaneYZAxisZavg: 0.0053
# 46. SAu10_UpperLipRaiser: 0.0053
# 47. SrightEyebrowRaised: 0.0052
# 48. SAu04_BrowLowerer: 0.0051
# 49. rightShoulderAngleavg: 0.0049
# 50. ShoulderCenter_ShoulderLeftPlaneYZAxisZavg: 0.0049
# 51. Sneutral: 0.0048
# 52. SxHeadOrientation: 0.0048
# 53. SAu23_LipTightener: 0.0048
# 54. Spine_ShoulderCenterPlaneYZAxisZavg: 0.0046
# 55. leanAngleavg: 0.0045
# 56. HipCenter_SpinePlaneZXAxisXavg: 0.0044
# 57. SAu05_UpperLidRaiser: 0.0042
# 58. ElbowLeft_WristLeftPlaneZXAxisXstdv: 0.0042
# 59. Spine_ShoulderCenterShoulderCenter_Headavg: 0.0041
# 60. ShoulderCenter_ShoulderLeftShoulderLeft_ElbowLeftavg: 0.0041
# 61. SAu02_OuterBrowRaiser: 0.004
# 62. ShoulderCenter_ShoulderLeftPlaneZXAxisXavg: 0.0038
# 63. SleftEyebrowLowered: 0.0037
# 64. Spine_ShoulderCenterShoulderCenter_ShoulderRightavg: 0.0037
# 65. SAu43_EyesClosed: 0.0037
# 66. ElbowLeft_WristLeftWristLeft_HandLeftavg: 0.0037
# 67. SAu07_LidTightener: 0.0037
# 68. ShoulderCenter_ShoulderRightShoulderRight_ElbowRightavg: 0.0036
# 69. Ssad: 0.0035
# 70. SleftEyebrowRaised: 0.0034
# 71. Spine_ShoulderCenterPlaneZXAxisXavg: 0.0033
# 72. HipCenter_SpineSpine_ShoulderCenterstdv: 0.0033
# 73. SAu14_Dimpler: 0.0033
# 74. HR: 0.0033
# 75. SAu17_ChinRaiser: 0.0033
# 76. HipCenter_SpinePlaneXYAxisYavg: 0.0032
# 77. Shappy: 0.0032
# 78. Svalence: 0.0032
# 79. ShoulderRight_ElbowRightPlaneZXAxisXavg: 0.0031
# 80. ShoulderLeft_ElbowLeftPlaneZXAxisXavg: 0.0031
# 81. RMSSD: 0.0031
# 82. ShoulderRight_ElbowRightPlaneXYAxisYavg: 0.0029
# 83. Spine_ShoulderCenterPlaneXYAxisYavg: 0.0028
# 84. ShoulderRight_ElbowRightElbowRight_WristRightavg: 0.0027
# 85. SmouthOpen: 0.0027
# 86. SAu15_LipCornerDepressor: 0.0027
# 87. SAu24_LipPressor: 0.0024
# 88. Spine_ShoulderCenterPlaneZXAxisXstdv: 0.0024
# 89. SleftEyeClosed: 0.0023
# 90. SAu25_LipsPart: 0.0023
# 91. WristLeft_HandLeftPlaneYZAxisZstdv: 0.0023
# 92. ElbowRight_WristRightPlaneYZAxisZavg: 0.0023
# 93. ShoulderCenter_ShoulderRightPlaneYZAxisZstdv: 0.0022
# 94. ShoulderLeft_ElbowLeftPlaneXYAxisYavg: 0.0021
# 95. SgazeDirectionForward: 0.0021
# 96. ShoulderRight_ElbowRightPlaneYZAxisZavg: 0.0021
# 97. ShoulderCenter_ShoulderRightPlaneXYAxisYstdv: 0.0019
# 98. HipCenter_SpinePlaneYZAxisZstdv: 0.0019
# 99. WristLeft_HandLeftPlaneXYAxisYstdv: 0.0018
# 100. ShoulderCenter_HeadPlaneZXAxisXstdv: 0.0018
# 101. ElbowRight_WristRightWristRight_HandRightstdv: 0.0018
# 102. ElbowLeft_WristLeftPlaneXYAxisYstdv: 0.0018
# 103. ShoulderLeft_ElbowLeftPlaneZXAxisXstdv: 0.0017
# 104. ElbowRight_WristRightPlaneZXAxisXavg: 0.0017
# 105. WristRight_HandRightKinectZAxisstdv: 0.0016
# 106. rightShoulderAnglestdv: 0.0016
# 107. ShoulderLeft_ElbowLeftElbowLeft_WristLeftstdv: 0.0016
# 108. ShoulderCenter_ShoulderLeftPlaneYZAxisZstdv: 0.0015
# 109. WristRight_HandRightPlaneZXAxisXavg: 0.0015
# 110. Spine_ShoulderCenterShoulderCenter_ShoulderRightstdv: 0.0015
# 111. SgazeDirectionLeft: 0.0015
# 112. ShoulderCenter_ShoulderRightPlaneZXAxisXstdv: 0.0015
# 113. SnKeyStrokes: 0.0015
# 114. ShoulderRight_ElbowRightPlaneXYAxisYstdv: 0.0014
# 115. HipCenter_SpinePlaneZXAxisXstdv: 0.0014
# 116. SrightEyeClosed: 0.0014
# 117. ShoulderRight_ElbowRightPlaneZXAxisXstdv: 0.0014
# 118. ElbowRight_WristRightPlaneXYAxisYavg: 0.0014
# 119. ElbowLeft_WristLeftPlaneYZAxisZstdv: 0.0014
# 120. SAu09_NoseWrinkler: 0.0013
# 121. leftShoulderAnglestdv: 0.0013
# 122. ShoulderCenter_ShoulderLeftShoulderLeft_ElbowLeftstdv: 0.0013
# 123. WristRight_HandRightPlaneXYAxisYavg: 0.0013
# 124. ElbowRight_WristRightWristRight_HandRightavg: 0.0012
# 125. SnSpecialKeys: 0.0012
# 126. ElbowLeft_WristLeftWristLeft_HandLeftstdv: 0.0012
# 127. leanAnglestdv: 0.0011
# 128. HipCenter_SpinePlaneXYAxisYstdv: 0.0011
# 129. Spine_ShoulderCenterShoulderCenter_ShoulderLeftstdv: 0.0011
# 130. Spine_ShoulderCenterPlaneYZAxisZstdv: 0.0011
# 131. ShoulderCenter_ShoulderLeftPlaneXYAxisYstdv: 0.0011
# 132. ShoulderCenter_ShoulderLeftPlaneZXAxisXstdv: 0.001
# 133. WristRight_HandRightKinectZAxisavg: 0.001
# 134. SnSpaces: 0.001
# 135. SAu26_JawDrop: 0.001
# 136. WristRight_HandRightPlaneZXAxisXstdv: 0.001
# 137. SnChars: 0.001
# 138. ShoulderCenter_HeadPlaneXYAxisYstdv: 0.001
# 139. SnMouseAct: 0.001
# 140. ShoulderLeft_ElbowLeftPlaneXYAxisYstdv: 0.0009
# 141. Spine_ShoulderCenterPlaneXYAxisYstdv: 0.0009
# 142. ElbowRight_WristRightPlaneYZAxisZstdv: 0.0009
# 143. ElbowRight_WristRightPlaneZXAxisXstdv: 0.0009
# 144. SnLeftClicked: 0.0009
# 145. ElbowRight_WristRightPlaneXYAxisYstdv: 0.0009
# 146. ShoulderLeft_ElbowLeftPlaneYZAxisZstdv: 0.0009
# 147. CharactersRatio: 0.0008
# 148. ShoulderCenter_ShoulderRightShoulderRight_ElbowRightstdv: 0.0008
# 149. Spine_ShoulderCenterShoulderCenter_Headstdv: 0.0008
# 150. WristRight_HandRightPlaneXYAxisYstdv: 0.0008
# 151. ShoulderRight_ElbowRightElbowRight_WristRightstdv: 0.0008
# 152. SgazeDirectionRight: 0.0007
# 153. ShoulderCenter_HeadPlaneYZAxisZstdv: 0.0007
# 154. ShoulderRight_ElbowRightPlaneYZAxisZstdv: 0.0007
# 155. SnErrorKeys: 0.0007
# 156. SAu20_LipStretcher: 0.0006
# 157. SnMouseDistance: 0.0006
# 158. SnDragged: 0.0006
# 159. ErrorKeyRatio: 0.0005
# 160. SnAppChange: 0.0004
# 161. SAu27_MouthStretch: 0.0004
# 162. SnWheel: 0.0003
# 163. SnTabfocusChange: 0.0003
# 164. SnDirectionKeys: 0.0003
# 165. SnShortcutKeys: 0.0002
# 166. SnDoubleClicked: 0.0002
# 167. SAu12_LipCornerPuller: 0.0002
# 168. SnRightClicked: 0.0001

# %% [markdown]
# # Resumen

# %%
# Imprimir solo los 10 primeros más importantes
print("Top ten feature_importance_df_full : \n")
for i, (feature, importance) in enumerate(zip(feature_importance_df_full['Feature'], feature_importance_df_full['Importance'])):
    if i < 10:  # Solo mostrar los primeros 10
        print(f"{i+1}. {feature}: {round(importance, 4)}")
    else:
        break
print()
print('-'*100)
print()

# Imprimir solo los 10 primeros más importantes
print("Top ten feature_importance_df_Stress : \n")
for i, (feature, importance) in enumerate(zip(feature_importance_df_Stress['Feature'], feature_importance_df_Stress['Importance'])):
    if i < 10:  # Solo mostrar los primeros 10
        print(f"{i+1}. {feature}: {round(importance, 4)}")
    else:
        break
# Out:
# Top ten feature_importance_df_full :
#
# 1. SzHeadOrientation: 0.0281
# 2. avgDepth(avg): 0.0281
# 3. Blok: 0.0215
# 4. Squality: 0.0206
# 5. WristLeft_HandLeft-PlaneZXAxisX(avg): 0.019
# 6. ShoulderCenter_Head-PlaneYZAxisZ(avg): 0.0174
# 7. SAu01_InnerBrowRaiser: 0.0159
# 8. avgDepth(stdv): 0.0157
# 9. SyHeadOrientation: 0.0157
# 10. Ssurprised: 0.015
#
# ----------------------------------------------------------------------------------------------------
#
# Top ten feature_importance_df_Stress :
#
# 1. NasaTLX: 0.0547
# 2. TemporalDemand: 0.0538
# 3. Frustration: 0.0533
# 4. MentalDemand: 0.049
# 5. Performance_rc: 0.0471
# 6. Effort: 0.0465
# 7. MentalEffort: 0.0451
# 8. Arousal_rc: 0.0353
# 9. PhysicalDemand: 0.034
# 10. Valence_rc: 0.032

# %%
# Lectura del archivo Excel
df_Stress = pd.read_excel("Copia de Behavioral-features - per minute.xlsx")
df_numericas_Stress = df_Stress.select_dtypes(include=['number'])
corr_matrix = df_numericas_Stress.corr()
corr_matrix['Stress'].sort_values(ascending=False)
# Out:
# Stress                                                      1.000000
# Frustration                                                 0.545560
# NasaTLX                                                     0.536578
# TemporalDemand                                              0.494337
# MentalDemand                                                0.460830
# Arousal_rc                                                  0.382362
# MentalEffort                                                0.371497
# PhysicalDemand                                              0.277444
# SCL                                                         0.234045
# Effort                                                      0.206962
# SAu06_CheekRaiser                                           0.202692
# SleftEyebrowLowered                                         0.180202
# SAu43_EyesClosed                                            0.180161
# avgDepthstdv                                                0.159818
# SAu10_UpperLipRaiser                                        0.154511
# ShoulderCenter_HeadPlaneZXAxisXavg                          0.149485
# Spine_ShoulderCenterPlaneZXAxisXavg                         0.149224
# ShoulderLeft_ElbowLeftPlaneZXAxisXstdv                      0.147304
# ElbowLeft_WristLeftPlaneXYAxisYstdv                         0.146568
# ElbowLeft_WristLeftPlaneZXAxisXstdv                         0.145151
# SrightEyeClosed                                             0.144810
# Ssad                                                        0.136696
# ShoulderLeft_ElbowLeftPlaneYZAxisZavg                       0.132672
# SleftEyeClosed                                              0.131693
# SrightEyebrowLowered                                        0.129267
# ShoulderRight_ElbowRightPlaneYZAxisZavg                     0.113225
# Spine_ShoulderCenterPlaneXYAxisYavg                         0.112114
# ElbowLeft_WristLeftWristLeft_HandLeftavg                    0.110963
# SAu24_LipPressor                                            0.110824
# WristLeft_HandLeftPlaneYZAxisZavg                           0.110150
# ShoulderCenter_HeadPlaneZXAxisXstdv                         0.107086
# Shappy                                                      0.102211
# Spine_ShoulderCenterShoulderCenter_Headavg                  0.101405
# ShoulderCenter_ShoulderLeftShoulderLeft_ElbowLeftavg        0.101213
# rightShoulderAngleavg                                       0.100745
# ShoulderCenter_ShoulderRightPlaneXYAxisYavg                 0.100745
# SgazeDirectionForward                                       0.100333
# SAu14_Dimpler                                               0.099510
# WristLeft_HandLeftPlaneZXAxisXstdv                          0.092349
# ShoulderRight_ElbowRightPlaneZXAxisXavg                     0.091092
# ShoulderCenter_HeadPlaneXYAxisYavg                          0.084300
# Sneutral                                                    0.081685
# ShoulderCenter_ShoulderRightShoulderRight_ElbowRightavg     0.077117
# Spine_ShoulderCenterPlaneZXAxisXstdv                        0.074121
# HipCenter_SpinePlaneZXAxisXavg                              0.070540
# Blok                                                        0.067958
# HR                                                          0.067732
# Sdisgusted                                                  0.063742
# SAu07_LidTightener                                          0.062411
# WristRight_HandRightPlaneXYAxisYavg                         0.059743
# SrightEyebrowRaised                                         0.059036
# ShoulderLeft_ElbowLeftPlaneZXAxisXavg                       0.057962
# ShoulderCenter_HeadPlaneYZAxisZstdv                         0.057023
# ElbowLeft_WristLeftPlaneZXAxisXavg                          0.056322
# WristRight_HandRightPlaneZXAxisXavg                         0.045787
# SnAppChange                                                 0.039219
# SAu27_MouthStretch                                          0.037558
# WristRight_HandRightKinectZAxisavg                          0.035635
# ElbowRight_WristRightWristRight_HandRightavg                0.035583
# SnLeftClicked                                               0.035179
# ShoulderCenter_HeadPlaneXYAxisYstdv                         0.033789
# WristLeft_HandLeftPlaneZXAxisXavg                           0.030285
# HipCenter_SpinePlaneXYAxisYavg                              0.030183
# Squality                                                    0.027111
# ElbowRight_WristRightPlaneXYAxisYavg                        0.025448
# ShoulderCenter_ShoulderLeftPlaneZXAxisXstdv                 0.022437
# Spine_ShoulderCenterShoulderCenter_ShoulderRightstdv        0.022196
# ShoulderRight_ElbowRightPlaneXYAxisYavg                     0.020203
# ShoulderCenter_ShoulderLeftPlaneXYAxisYstdv                 0.019074
# leftShoulderAnglestdv                                       0.019074
# WristLeft_HandLeftPlaneXYAxisYstdv                          0.018088
# ShoulderCenter_ShoulderLeftPlaneYZAxisZavg                  0.017973
# SAu04_BrowLowerer                                           0.017454
# ShoulderCenter_ShoulderLeftPlaneYZAxisZstdv                 0.017120
# ShoulderRight_ElbowRightPlaneYZAxisZstdv                    0.015749
# SAu20_LipStretcher                                          0.015619
# RMSSD                                                       0.015458
# Spine_ShoulderCenterShoulderCenter_ShoulderLeftstdv         0.014813
# Sangry                                                      0.010159
# rightShoulderAnglestdv                                      0.007216
# ShoulderCenter_ShoulderRightPlaneXYAxisYstdv                0.007216
# ElbowRight_WristRightPlaneZXAxisXavg                        0.005294
# CharactersRatio                                             0.002811
# ShoulderCenter_ShoulderRightPlaneYZAxisZstdv                0.001430
# ShoulderLeft_ElbowLeftPlaneYZAxisZstdv                     -0.001558
# ShoulderCenter_ShoulderLeftShoulderLeft_ElbowLeftstdv      -0.004833
# SnTabfocusChange                                           -0.005375
# HipCenter_SpineSpine_ShoulderCenterstdv                    -0.007227
# ShoulderLeft_ElbowLeftElbowLeft_WristLeftavg               -0.007232
# ShoulderLeft_ElbowLeftPlaneXYAxisYavg                      -0.007969
# SnMouseAct                                                 -0.010068
# SnMouseDistance                                            -0.010367
# HipCenter_SpinePlaneXYAxisYstdv                            -0.013227
# ElbowRight_WristRightPlaneYZAxisZavg                       -0.013468
# leanAnglestdv                                              -0.014895
# Spine_ShoulderCenterPlaneYZAxisZstdv                       -0.014895
# ShoulderCenter_ShoulderRightPlaneZXAxisXstdv               -0.015882
# ElbowRight_WristRightPlaneZXAxisXstdv                      -0.016347
# SnDoubleClicked                                            -0.016515
# Spine_ShoulderCenterShoulderCenter_Headstdv                -0.017222
# SnRightClicked                                             -0.018390
# SnDragged                                                  -0.018433
# ElbowRight_WristRightPlaneYZAxisZstdv                      -0.020823
# Spine_ShoulderCenterShoulderCenter_ShoulderRightavg        -0.022478
# HipCenter_SpinePlaneYZAxisZstdv                            -0.022667
# ShoulderLeft_ElbowLeftPlaneXYAxisYstdv                     -0.023991
# ElbowLeft_WristLeftPlaneYZAxisZavg                         -0.024401
# SAu12_LipCornerPuller                                      -0.024837
# ShoulderLeft_ElbowLeftElbowLeft_WristLeftstdv              -0.029073
# Spine_ShoulderCenterPlaneXYAxisYstdv                       -0.029119
# ShoulderRight_ElbowRightElbowRight_WristRightstdv          -0.030288
# ErrorKeyRatio                                              -0.030878
# ShoulderRight_ElbowRightElbowRight_WristRightavg           -0.033771
# ElbowLeft_WristLeftWristLeft_HandLeftstdv                  -0.033940
# avgDepthavg                                                -0.034850
# SnWheel                                                    -0.036547
# ShoulderCenter_ShoulderLeftPlaneZXAxisXavg                 -0.037196
# ElbowRight_WristRightPlaneXYAxisYstdv                      -0.038579
# Svalence                                                   -0.047915
# ElbowLeft_WristLeftPlaneYZAxisZstdv                        -0.050981
# SAu17_ChinRaiser                                           -0.051485
# Spine_ShoulderCenterPlaneYZAxisZavg                        -0.051937
# leanAngleavg                                               -0.051937
# SnSpaces                                                   -0.052870
# ElbowRight_WristRightWristRight_HandRightstdv              -0.055454
# SnChars                                                    -0.059315
# SnShortcutKeys                                             -0.060728
# WristRight_HandRightPlaneZXAxisXstdv                       -0.062372
# WristRight_HandRightKinectZAxisstdv                        -0.062620
# WristRight_HandRightPlaneXYAxisYstdv                       -0.069624
# ShoulderCenter_ShoulderRightPlaneZXAxisXavg                -0.071855
# SgazeDirectionLeft                                         -0.073224
# SAu09_NoseWrinkler                                         -0.074647
# SxHeadOrientation                                          -0.076195
# SnDirectionKeys                                            -0.076769
# SnKeyStrokes                                               -0.077633
# ShoulderRight_ElbowRightPlaneZXAxisXstdv                   -0.077884
# ShoulderCenter_ShoulderRightShoulderRight_ElbowRightstdv   -0.079299
# ShoulderCenter_ShoulderRightPlaneYZAxisZavg                -0.081524
# WristLeft_HandLeftPlaneYZAxisZstdv                         -0.083085
# SnErrorKeys                                                -0.084252
# ElbowLeft_WristLeftPlaneXYAxisYavg                         -0.090899
# HipCenter_SpinePlaneYZAxisZavg                             -0.091307
# SAu23_LipTightener                                         -0.092004
# SAu01_InnerBrowRaiser                                      -0.095954
# Sscared                                                    -0.096452
# SnSpecialKeys                                              -0.097852
# SgazeDirectionRight                                        -0.098603
# HipCenter_SpineSpine_ShoulderCenteravg                     -0.101169
# HipCenter_SpinePlaneZXAxisXstdv                            -0.111299
# SAu02_OuterBrowRaiser                                      -0.118027
# SmouthOpen                                                 -0.118261
# SAu15_LipCornerDepressor                                   -0.119547
# SleftEyebrowRaised                                         -0.135075
# SAu26_JawDrop                                              -0.140225
# SAu25_LipsPart                                             -0.147582
# SzHeadOrientation                                          -0.153034
# WristLeft_HandLeftPlaneXYAxisYavg                          -0.154218
# ShoulderCenter_ShoulderLeftPlaneXYAxisYavg                 -0.166101
# leftShoulderAngleavg                                       -0.166101
# Dominance                                                  -0.175270
# ShoulderRight_ElbowRightPlaneXYAxisYstdv                   -0.193997
# SyHeadOrientation                                          -0.205757
# ShoulderCenter_HeadPlaneYZAxisZavg                         -0.210188
# Performance_rc                                             -0.220332
# Spine_ShoulderCenterShoulderCenter_ShoulderLeftavg         -0.224041
# SAu05_UpperLidRaiser                                       -0.281176
# Ssurprised                                                 -0.309870
# Valence_rc                                                 -0.414338
# Name: Stress, dtype: float64
